# %% [markdown]
# # Executive Dashboard — procurement-kpi-analysis

# %%
from pathlib import Path
import sys
import importlib

root = Path.cwd()
if (root / 'cases').exists():
    project_root = root
else:
    project_root = root.parent
sys.path.append(str(project_root))

case_dir = project_root / 'cases' / 'procurement-kpi-analysis'
data_path = case_dir / 'Procurement KPI Analysis Dataset.csv'
module_base = 'cases.procurement-kpi-analysis.src'

# %%
pipeline = importlib.import_module(f"{module_base}.pipeline")

pipeline.run()
