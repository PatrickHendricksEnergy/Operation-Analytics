# %%
# Setup: make repo root importable and define module_base
from pathlib import Path
import sys

repo_root = Path.cwd().resolve().parents[3]
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

module_base = "cases.inventory_analysis.src"

# %% [markdown]
# # EDA — inventory_analysis

# %%
from pathlib import Path
import sys
import importlib

root = Path.cwd()
if (root / 'cases').exists():
    project_root = root
else:
    project_root = root.parent
sys.path.append(str(project_root))

case_dir = project_root / 'cases' / 'inventory_analysis'

# %%
data_loading = importlib.import_module(f"{module_base}.data_loading")

print('Dataset dir:', data_loading.detect_dataset_dir(case_dir))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data_loading = importlib.import_module(f"{module_base}.data_loading")
#       3 print('Dataset dir:', data_loading.detect_dataset_dir(case_dir))
#
# NameError: name 'module_base' is not defined
