# %%
# Setup: make repo root importable and define module_base
from pathlib import Path
import sys

repo_root = Path.cwd().resolve().parents[3]
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

module_base = "cases.inventory_analysis.src"

# %% [markdown]
# # Demand Forecasting — inventory_analysis

# %%
from pathlib import Path
import sys
import importlib

root = Path.cwd()
if (root / 'cases').exists():
    project_root = root
else:
    project_root = root.parent
sys.path.append(str(project_root))

case_dir = project_root / 'cases' / 'inventory_analysis'

# %%
pipeline = importlib.import_module(f"{module_base}.pipeline")

pipeline.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pipeline = importlib.import_module(f"{module_base}.pipeline")
#       3 pipeline.run()
#
# NameError: name 'module_base' is not defined
