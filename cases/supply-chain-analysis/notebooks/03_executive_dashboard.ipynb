# %% [markdown]
# # Executive Dashboard — supply-chain-analysis

# %%
from pathlib import Path
import sys
import importlib

root = Path.cwd()
if (root / 'cases').exists():
    project_root = root
else:
    project_root = root.parent
sys.path.append(str(project_root))

case_dir = project_root / 'cases' / 'supply-chain-analysis'
data_path = case_dir / 'supply_chain_data.csv'
module_base = 'cases.supply-chain-analysis.src'

# %%
pipeline = importlib.import_module(f"{module_base}.pipeline")

pipeline.run()
